# %%
### installing required packages ### 
#pip install rdflib
#pip install SPARQLWrapper
#pip install matplotlib
#pip install shapely
#pip install fiona 
#pip install pyproj
#pip install GDAL
#pip install geopandas
#pip install foursquare
#pip install -q keras

# %%
! pip install fuzzywuzzy 
! pip install dash_bootstrap_components
# Out:
# ...
#      |████████████████████████████████| 207 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 7.3 MB 29.9 MB/s
# ...
#      |████████████████████████████████| 25.3 MB 66 kB/s
# ...
#      |████████████████████████████████| 357 kB 72.3 MB/s
# ...
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3821 sha256=df24345f08b68e334770de8abb011866726d14ce8e2e5dbeebb5c2926c0d642f
#   Stored in directory: /root/.cache/pip/wheels/00/f9/c7/1a6437d794ed753ea9bc9079e761d4fc803a1f1f5d3697b9ec
# ...
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4089 sha256=c567efda891bbda4d00e7c2a91a1a99438a4ab17b9f5b9f07c013f0700000618
#   Stored in directory: /root/.cache/pip/wheels/ec/6b/81/05aceabd8b27f724e2c96784016287cc1bfbc349ebfda451de
# ...
#   Created wheel for dash-table: filename=dash_table-5.0.0-py3-none-any.whl size=3911 sha256=f80050b4ad96613830be00cee9f6bbaf9992bb29ff56feb053ad1cb264e3f92b
# ...

# %%
pip install SPARQLWrapper -q
# Out:
#      |████████████████████████████████| 407 kB 8.0 MB/s
#      |████████████████████████████████| 45 kB 3.3 MB/s

# %%
# !pip install dash-cytoscape -q
# !pip install jupyter-dash -q
# !pip install dash  
# !pip install dash-html-components
# !pip install dash-core-components
# !pip install dash-table
! pip install dash_daq -q
# Out:
#      |████████████████████████████████| 3.6 MB 4.3 MB/s
#      |████████████████████████████████| 7.3 MB 59.2 MB/s
#      |████████████████████████████████| 25.3 MB 66 kB/s
#      |████████████████████████████████| 357 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 642 kB 4.4 MB/s
# ...

# %%
# read data from google drive 
import keras
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Data From inside Airbnb
#listing = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/listing.csv")
# reviews_and_comments = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments.csv")
# reviews_and_comments1 =pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments1.csv")
# reviews_and_comments2 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments2.csv")
# reviews_and_comments3 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments3.csv")
# reviews_and_comments4 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments4.csv")
# reviews_and_comments5 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments5.csv")
# reviews_and_comments6 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments6.csv")
# reviews_and_comments7 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments8.csv")

# Compining reviews and comments datasets (comments about properities)
# datasets= [reviews_and_comments, 
#            reviews_and_comments1, 
#            reviews_and_comments2, 
#            reviews_and_comments3, 
#            reviews_and_comments4,
#            reviews_and_comments5, 
#            reviews_and_comments6, 
#            reviews_and_comments7]
# reviews_and_comments = pd.concat(datasets)
# reviews_and_comments = reviews_and_comments[["listing_id", "comments"]]



# Selecting some variables from listing dataset (dataset about properities)
# listing = listing[["id",
#                   "listing_url", 
#                   "name", 
#                   "description",
#                   "neighborhood_overview",
#                   "picture_url", 
#                   "host_about",
#                   "host_is_superhost", 
#                   "neighbourhood",
#                   "neighbourhood_cleansed", 
#                   "latitude",
#                   "longitude",
#                   "property_type",
#                   "accommodates",
#                   "price",
#                   "bedrooms", 
#                   "review_scores_location"]]

# Data from TFL (transport for London)
#underground_stations = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/London underground stations.csv",sep=",", encoding='cp1252')

# Data from Kaggel 
#tripadvisor_european_restaurants = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/tripadvisor_european_restaurants.csv")

# filter tripadvisor_european_restaurants based on region (Greater London or London)
# Greater_London = tripadvisor_european_restaurants["region"] == "Greater London"
# London = tripadvisor_european_restaurants["region"] == "London"
# London_restaurants = tripadvisor_european_restaurants[Greater_London | London]

# London_restaurants = London_restaurants[["restaurant_name", 
#                                          "original_location", 
#                                          "region", 
#                                          "province", 
#                                          "city", 
#                                          "address", 
#                                          "latitude", 
#                                          "longitude", 
#                                          "meals", 
#                                          "cuisines", 
#                                          "special_diets",
#                                          "vegetarian_friendly",
#                                          "vegan_options",
#                                         "gluten_free", 
#                                         "avg_rating"
#                                          ]]

# Data from UK gov website about crime in London
#crime_data = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/SNT.csv")

# selecting some varibales from crime_data
#crime_data = crime_data[["SNT Borough Name","SNT Name","MajorText","average_crime_number"]]

# Data from UK gov website about Embassies in London 
#embassy = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/Embassy.csv", sep=",", encoding='cp1252')

# Create and connect database 
import sqlite3 as sql
from sqlalchemy import create_engine
airbnb_connection = create_engine("sqlite:////content/drive/MyDrive/MSc project/datasets/Airbnb.db")
# reviews_SentAnalysis.to_sql("reviews", airbnb_connection)

# create tables 
#listing.to_sql('listing', airbnb_connection)
#embassy.to_sql('embassy', airbnb_connection)
#crime_data.to_sql('crime_data', airbnb_connection)
#London_restaurants.to_sql('London_restaurants', airbnb_connection)
#transportation.to_sql('transportation', airbnb_connection)
#venues.to_sql('venues', airbnb_connection)
#underground_stations.to_sql("underground_stations",airbnb_connection )
#reviews_and_comments.to_sql("reviews", airbnb_connection)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# *  # * #  THIS CODE USED FOR ANALYSE COMMENTS ABOUT PROPERITIES  # *  # * #

# from nltk.sentiment import SentimentIntensityAnalyzer
# import nltk
# nltk.download()
# nltk.download([
#      "names",
#      "stopwords",
#      "state_union",
#      "averaged_perceptron_tagger",
#      "vader_lexicon",
#     "punkt",
# ])
# nltk.download('words')


# # read data from google drive 
# import keras
# import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')

# # Data From inside Airbnb
# #reviews_and_comments = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments.csv")
# #reviews_and_comments = reviews_and_comments[["listing_id", "comments"]]
# # reviews_and_comments1 =pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments1.csv")
# # reviews_and_comments1 = reviews_and_comments1[["listing_id", "comments"]]
# # reviews_and_comments2 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments2.csv")
# # reviews_and_comments2 = reviews_and_comments2[["listing_id", "comments"]]
# # reviews_and_comments3 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments3.csv")
# # reviews_and_comments3 = reviews_and_comments3[["listing_id", "comments"]]
# # reviews_and_comments4 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments4.csv")
# # reviews_and_comments4 = reviews_and_comments4[["listing_id", "comments"]]
# # reviews_and_comments5 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments5.csv")
# # reviews_and_comments5 = reviews_and_comments5[["listing_id", "comments"]]
# # reviews_and_comments6 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments6.csv")
# # reviews_and_comments6 = reviews_and_comments6[["listing_id", "comments"]]
# reviews_and_comments7 = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_and_comments8.csv")
# reviews_and_comments7 = reviews_and_comments7[["listing_id", "comments"]]


# words = set(nltk.corpus.words.words())
# sentAnalyse = SentimentIntensityAnalyzer()
# datasets= [reviews_and_comments, 
#            reviews_and_comments1,
#            reviews_and_comments2, 
#            reviews_and_comments3, 
#            reviews_and_comments4,
#            reviews_and_comments5, 
#            reviews_and_comments6, 
#            reviews_and_comments7]

#reviews_and_comments = reviews_and_comments[["listing_id", "comments"]]

# listing_id = []
# comments = []
# polarity_scores = []

# for review in range(len(reviews_and_comments7)):
#     english_comment = " ".join(w for w in nltk.wordpunct_tokenize(str(reviews_and_comments7["comments"][review])) \
#         if w.lower() in words or not w.isalpha())
#     comment = sentAnalyse.polarity_scores(english_comment)
#     listing_id.append(reviews_and_comments6["listing_id"][review])
#     comments.append(english_comment)
#     polarity_scores.append(comment)
# reviews = pd.DataFrame({"listing_id":listing_id, "comments": comments, "polarity_scores": polarity_scores})
#reviews.to_csv("reviews8.csv", index=False)




# datasets= [pd.read_csv("reviews1.csv"), 
#            pd.read_csv("reviews2.csv"), 
#            pd.read_csv("reviews3.csv"), 
#            pd.read_csv("reviews4.csv"), 
#            pd.read_csv("reviews5.csv"),
#            pd.read_csv("reviews6.csv"), 
#            pd.read_csv("reviews7.csv")]
# reviews_SentAnalysis = pd.concat(datasets)
# # remove duplicated raws in the reviews dataframe. 
# reviews_SentAnalysis = reviews_SentAnalysis.drop_duplicates()
# # drop rows with any null value
# reviews_SentAnalysis.dropna(how ="any", inplace= True)

# Clean Data From inside Airbnb of properity comments 
# reviews_SentAnalysis = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/reviews_SentAnalysis.csv")

# convert polarity_scores value from string to dict
# from ast import literal_eval
# dic = []
# for i in range(len(reviews_SentAnalysis)):
#   dic.append(literal_eval(reviews_SentAnalysis["polarity_scores"][i]))
# reviews_SentAnalysis["polarity_scores"] = dic

# # sprint each value of polarity_scores in a column in a new datafram
# polarity_scores = reviews_SentAnalysis["polarity_scores"].apply(pd.Series)
# # merge polarity_scores with reviews_SentAnalysis dataframe
# reviews_SentAnalysis = pd.concat([reviews_SentAnalysis, polarity_scores], axis=1)
# # Agregate the value using MEAN and save the final datafream into a csv file
# reviews_SentAnalysis = reviews_SentAnalysis.groupby('listing_id').aggregate({'neg': 'mean',
#                                                                      'neu': 'mean', 
#                                                                       'pos': 'mean'}).to_csv("reviews_SentAnalysis_Grouped.csv")
# reviews_SentAnalysis = pd.read_csv("reviews_SentAnalysis_Grouped.csv")
# # store the csv file in a table in the database
# reviews_SentAnalysis.to_sql("reviews", airbnb_connection)

# %%
# *  # * #  THIS CODE USED FOR CLEANING AND AGREGATING CRIME DATA  # *  # * #
# read the crime data from csv file in google drive
# crime_data = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/SNT.csv")
# # drop cloumns that would not be used in the analysis to save storge space and time
# crime_data = crime_data.drop(['SNT Name', 'MinorText'], axis=1)
# # select subset of the data where crime_number is the total number of crime 
# # from January 2011 until August 2021 
# crime_data = crime_data[["crime_number", 'SNT Borough Name', 'MajorText']]
# # Group crime data based on the Borough Name and its type 
# crime_data = crime_data.groupby(['SNT Borough Name', 'MajorText'] ).aggregate({'crime_number': 'mean' }).to_csv("crime_data_Grouped.csv")
# Create a new table in the database for crime data 
#crime_data.to_sql("crime_per_month", airbnb_connection)

# crime_data = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/crime_data_Grouped.csv")
# # select hate crime only 
# crime_data = crime_data[crime_data['MajorText'] == "Hate"]
# crime_data = crime_data[["SNT Borough Name", "crime_number"]]
# # check how many neighbourhoods have crime rate 
# print(listing['neighbourhood_cleansed'].isin(crime_data['SNT Borough Name']).value_counts())
# # change column name
# listing.rename(columns={'neighbourhood_cleansed': 'neighbourhood'}, inplace=True)
# crime_data.rename(columns={'SNT Borough Name': 'neighbourhood'}, inplace=True)

# #create id column 
# id = []
# for i in range(1, len(crime_data)+1): 
#   id.append(i)
# crime_data["id"] = id 

# #save data in csv files 
# crime_data.to_csv("crime_data_ID.csv", index=False)
# listing.to_csv("listing.csv", index=False)

# %%
# *  # * #  THIS CODE USED FOR Mrge Crime Categories into listing table  # *  # * #
# listing = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/listing.csv")
# crime_data = pd.read_csv("/content/drive/MyDrive/Airbnb datasets/crime_data_ID.csv")
# listing = pd.merge(crime_data, listing, how="inner", on= "crime_id")
# listing = listing.drop(['SNT Borough Name'], axis=1)
#Summary Statistics of crime_number
#listing["crime_number"].describe()
""" 
count    73361.000000
mean       189.181186
std         46.759620
min          9.800000
25%        162.757143
50%        207.685714
75%        220.529412
max        264.783333 
"""
# the crime categorise into 3 differnt categories based on The interquartile range: Q1, Q2 and Q#
import pandas as pd

listing = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv")
crime_categories = []
color = []
for i in listing["crime_number"]: 
  if i < 163: 
    crime_categories.append("low")
    # green color
    color.append("green")
  if (i >= 163) and (i <= 208): 
    crime_categories.append("middle")
    # orange color
    color.append("orange")
  if i > 208:
    crime_categories.append("high")
    # red color
    color.append("red")
listing['crime_categories'] = crime_categories
listing["color"] = color

# %%
listing.to_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv", index= False)

# %%
import pandas as pd 
listing = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv")
link = []
id_test = []
for i in range(len(listing["index"])): 
  link.append("/"+str(i))
  id_test.append(str(i))

# %%
listing['link'] = link
listing['id_test'] = id_test

# %%
import sqlite3 as sql
import pandas as pd
from sqlalchemy import create_engine
airbnb_connection = create_engine("sqlite:////content/drive/MyDrive/MSc project/datasets/Airbnb.db")
listing = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing.csv")
reviews = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/reviews.csv")
listing = pd.merge(reviews, listing, how="inner", on= "id")

# %%
import sqlite3 as sql
import pandas as pd
from sqlalchemy import create_engine
airbnb_connection = create_engine("sqlite:////content/drive/MyDrive/MSc project/datasets/Airbnb.db")
underground_stations = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/underground_stations.csv")
underground_stations.to_sql("underground_stations1", airbnb_connection,  index= False)

# %%
listing.head()
# Out:
#       id       neg       neu       pos  ...  color code   color    link  id_test
# 0  11551  0.016115  0.673250  0.310627  ...     #FF0000     red  /38584    38584
# 1  13913  0.009208  0.635917  0.354917  ...     #FF0000     red  /28687    28687
# 2  15400  0.016850  0.698758  0.284400  ...     #00FF00   green  /32900    32900
# 3  17402  0.037900  0.672167  0.273300  ...     #00FF00   green  /65210    65210
# 4  25123  0.015379  0.600095  0.378580  ...     #FFFF00  orange    /400      400
#
# [5 rows x 29 columns]

# %%
listing.to_sql("listing2", airbnb_connection,  index= False)

# %%
listing['id_test']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 22004    22004
# 22005    22005
# 22006    22006
# 22007    22007
# 22008    22008
# Name: id_test, Length: 22009, dtype: object

# %%
import pandas as pd
listing = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv")
pathname = '/139'
print(pathname[1:])
print(type(listing.id_test[0]))
print(int(pathname[1:]) in listing.id_test)
# Out:
# 139
# <class 'numpy.int64'>
# True

# %%
type(listing.listing_url[0])
# Out:
# str

# %%
pathname = '/900'
if len(pathname) > 1:
     pathname =[pathname[1:]]
     print(pathname)
     df= listing[(listing['id_test'].isin(pathname))]
     print(df)
else:
    print('layout')
# Out:
# ['900']
#      crime_number  crime_id  index        id  ... color code color  link id_test
# 900    219.347619         5  41649  30895716  ...    #FF0000   red  /900     900
#
# [1 rows x 25 columns]

# %%
import sqlite3
try:
    sqliteConnection = sqlite3.connect('/content/drive/MyDrive/MSc project/datasets/Airbnb.db')
    cursor = sqliteConnection.cursor()
except sqlite3.Error as error:
    print("Error while connecting to sqlite", error)
# Out:
# Database created and Successfully Connected to SQLite

# %%
import sqlite3
sqliteConnection = sqlite3.connect('/content/drive/MyDrive/MSc project/datasets/Airbnb.db')
cursor = sqliteConnection.cursor()
print("Database created and Successfully Connected to SQLite")
# Out:
# Database created and Successfully Connected to SQLite

# %%
display_page(pathname)

# %%
listing = listing.dropna()

# %%
len(listing)
# Out:
# 22009

# %%
len(listing['name'].unique())
# Out:
# 21782

# %%
# import pandas as pd
# crime_month = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/SNT.csv")
# # number of menth reporting crime 
# month_number = crime_month.shape [1]  - 6

# df = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/SNT -Copy1.csv")
# df_group = df.groupby('SNT Borough Name').aggregate({'crime_number': 'sum'}).to_csv("Borough crime.csv")
# # claculate average crime per month in each Borough in London 
# df_group = pd.read_csv("/content/Borough crime.csv")
# df_group["average_crime"] = df_group["crime_number"] / month_number

# %%
df_group.to_csv("Borough crime.csv", index= False)

# %%
 borough_crime= pd.read_csv("Borough crime.csv")
 location_crime = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/London Boroughs.csv")
df_group = pd.merge(borough_crime, location_crime, how="inner", on= "SNT Borough Name")
df_group.to_csv("Borough crime location.csv", index= False)

# %%
listing.to_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories2.csv")

# %%
# check how many neighbourhoods have crime rate 
crime_data['SNT Borough Name'].isin(listing['neighbourhood_cleansed']).value_counts()
# Out:
# True     13713
# False      126
# Name: SNT Borough Name, dtype: int64

# %%
# check if the resturant/cafe name from FoureSqure match the resurant name from London_restaurants/cafe 
exists  = "The Blues Kitchen" in set(London_restaurants.restaurant_name)
print(exists)
# Out:
# False

# %%
listing = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv")
listing.to_sql("listing1", airbnb_connection)
crime = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/London Boroughs crime location.csv")
crime.to_sql("crime", airbnb_connection)

# %%
#Fouresqure API 
#explore Endpoint
import pandas as pd
import json, requests
from SPARQLWrapper import SPARQLWrapper2

url = 'https://api.foursquare.com/v2/venues/explore?'
limit = 20
def things_to_do():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='things to do',
  limit= 15
  )
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text) 
  activity = []
  activity_info = []
  for venue in range(len(data["response"]["groups"][0]["items"])):
     activity.append(str(data["response"]["groups"][0]["items"][venue]["venue"]["name"]).replace(" ", "_"))
  for venue in range(len(activity)):
    venue_name = activity[venue]
    sparql = SPARQLWrapper2("http://dbpedia.org/sparql")
    sparql.setQuery("""
    SELECT ?label ?thumbnail
    WHERE {
        <http://dbpedia.org/resource/"""+venue_name+""">
            dbo:abstract ?label ; 
            dbo:thumbnail ?thumbnail .
        FILTER (lang(?label) = 'en')
    }
    """)
  
    for result in sparql.query().bindings:
      if (result["label"].value != []):
        activity_info.append(venue_name +","+ result["label"].value)
  return data, activity_info


def breakfast():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='breakfast',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def lunch():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='lunch',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def dinner():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.2758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='Dinner',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def nightlife():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='nightlife',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def coffee():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='Café',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def print_venue(data):
  for venue in  range(len(data["response"]["groups"][0]["items"])):
    print("Venue_Name: " + str(data["response"]["groups"][0]["items"][venue]["venue"]["name"]))
    print("Venue_type: "+ str(data["response"]["groups"][0]["type"]))
    print("Venue_Summary: " + str(data["response"]["groups"][0]["items"][venue]["reasons"]["items"][0]["summary"]))
    print("Venue_Location: " + str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["formattedAddress"]))
    print("Venue_lat: "+ str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["labeledLatLngs"][0]["lat"]))
    print("Venuelng: "+ str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["labeledLatLngs"][0]["lng"]))
    print("distance: "+ str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["distance"]))
    print("category: " +str(data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"]))
    print("#################")

def bus_stop():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='bus stop',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def train():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500  meters
  query='Train Station',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

def print_data_transportation(data):
   for venue in  range(len(data["response"]["groups"][0]["items"])):
      if data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"] == "Train Station":
        print("Venue_Name: " + str(data["response"]["groups"][0]["items"][venue]["venue"]["name"]))
        print("Venue_type: "+ str(data["response"]["groups"][0]["type"]))
        print("Venue_Summary: " + str(data["response"]["groups"][0]["items"][venue]["reasons"]["items"][0]["summary"]))
        print("Venue_Location: " + str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["formattedAddress"]))
        print("Venue_lat: "+ str(data["response"]["groups"][0]["items"][0]["venue"]["location"]["lat"]))
        print("Venue_lng: "+ str(data["response"]["groups"][0]["items"][0]["venue"]["location"]["lng"]))
        print("distance: "+ str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["distance"]))
        print("category: " +str(data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"]))
        print("#################")

# insert data into database tables 
def insertIntoDB_data_transportation(data):
  for venue in  range(len(data["response"]["groups"][0]["items"])):
    if data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"] == "Train Station" or "bus stop":
      Venue_Name = data["response"]["groups"][0]["items"][venue]["venue"]["name"]
      Venue_typ = data["response"]["groups"][0]["type"]
      Venue_Summary = data["response"]["groups"][0]["items"][venue]["reasons"]["items"][0]["summary"]
      Venue_Location = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["formattedAddress"]
      Venue_lat = data["response"]["groups"][0]["items"][0]["venue"]["location"]["lat"]
      Venue_lng = data["response"]["groups"][0]["items"][0]["venue"]["location"]["lng"]
      distance = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["distance"]
      category = data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"]
      datapoint = {"Venue_Name": Venue_Name, 
              "Venue_typ": Venue_typ, 
              "Venue_Summary": Venue_Summary, 
              "Venue_Location": Venue_Location, 
              "Venue_lat": Venue_lat, 
              "Venue_lng": Venue_lng, 
              "distance": distance, 
              "category": category}
    if data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"] == "Train Station":
        train = pd.DataFrame(datapoint)
    #train.to_sql('train', airbnb_connection)
    if data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"] == "Bus stop":
      bus = pd.DataFrame(datapoint)
    #bus.to_sql('bus', airbnb_connection)

def insertIntoDB_data_venues(data):
  for venue in  range(len(data["response"]["groups"][0]["items"])):
    Venue_Name = data["response"]["groups"][0]["items"][venue]["venue"]["name"]
    Venue_typ = data["response"]["groups"][0]["type"]
    Venue_Summary = data["response"]["groups"][0]["items"][venue]["reasons"]["items"][0]["summary"]
    Venue_Location = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["formattedAddress"]
    Venue_lat = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["labeledLatLngs"][0]["lat"]
    Venue_lng = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["labeledLatLngs"][0]["lng"]
    distance = data["response"]["groups"][0]["items"][venue]["venue"]["location"]["distance"]
    category = data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"]
    data = {"Venue_Name": Venue_Name, 
            "Venue_typ": Venue_typ, 
            "Venue_Summary": Venue_Summary, 
            "Venue_Location": Venue_Location, 
            "Venue_lat": Venue_lat, 
            "Venue_lng": Venue_lng, 
            "distance": distance, 
            "category": category}
  venues = pd.DataFrame(data)
  venues.to_sql('venues', airbnb_connection)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import dash_bootstrap_components as dbc
from dash import html

# %%
def things_to_do():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='things to do',
  limit= 15
  )
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text) 
  activity = []
  activity_info = []
  for venue in range(len(data["response"]["groups"][0]["items"])):
     activity.append(str(data["response"]["groups"][0]["items"][venue]["venue"]["name"]).replace(" ", "_"))
  for venue in range(len(activity)):
    venue_name = activity[venue]
    sparql = SPARQLWrapper2("http://dbpedia.org/sparql")
    sparql.setQuery("""
    SELECT ?label ?thumbnail
    WHERE {
        <http://dbpedia.org/resource/"""+venue_name+""">
            dbo:abstract ?label ; 
            dbo:thumbnail ?thumbnail .
        FILTER (lang(?label) = 'en')
    }
    """)
    
    for result in sparql.query().bindings:
      print(result)
      if (result["label"].value != []):
        #ven_name.append(venue_name)
        activity_info.append(result["label"].value)

    Venue_Name = []
    Venue_Location = []
    distance = []
    category = []
    for venue in  range(len(data["response"]["groups"][0]["items"])):
        Venue_Name.append(str(data["response"]["groups"][0]["items"][venue]["venue"]["name"]))
        Venue_Location.append(str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["formattedAddress"]))
        distance.append(str(data["response"]["groups"][0]["items"][venue]["venue"]["location"]["distance"]))
        category.append(str(data["response"]["groups"][0]["items"][venue]["venue"]['categories'][0]["shortName"]))

    data= pd.DataFrame({"Venue_Name": Venue_Name, "Venue_Location": Venue_Location, "distance": distance, "category":category })

    Venue_Name = []
    Venue_Location = []
    distance = []
    category = []
    info = []

    for j in range(len(data)):
        for i in range(len(activity_info)):
            print("i "+str(i))
            print("j "+str(j))
            venue_name = fuzz.partial_ratio(activity_info[i], data["Venue_Name"][j])
            if venue_name > 50:
                    Venue_Name.append(str(data["Venue_Name"][j]))
                    distance.append(str(data["distance"][j]))
                    info.append(str(activity_info[i]))
                    Venue_Location.append(str(data["Venue_Location"][j][:2]))
                    category.append(str(data["category"][j]))

            print(venue_name)
            print("------")

        print("len name = " + str(len(Venue_Name)))
        if len(Venue_Name) == 0:
              return [html.H4("Sorry there is no Train station near you!", className="card-title, text-success, text-center")]
        else:
              venue_list = []
              for i in range(len(Venue_Name)):
                  venue_list.append(dbc.Card(html.Div([
                      html.H4(str(Venue_Name[i]), className="card-title, text-success"),
                      html.Div(str(category[i])),
                      html.Div("Address: " + str(Venue_Location[i])),
                      html.Div("info: " + str(info[i])),
                      html.Div("Distance: " + str(distance[i]) + " m"),
                  ], ), style={"width": "30.5rem"}, ), ),

              return venue_list

# %%
things_to_do()
# Out:
# {'label': Value(literal:'The Ritzy is a cinema in Brixton, London, England. It is a Grade II listed building. It is managed by Picturehouse Cinemas, who were bought by Cineworld in 2012. The cinema opened on 11 March 1911 as "the Electric Pavilion". It was built by E.C. Homer and Lucas for Israel Davis, one of a noted family of cinema developers, and was one of England\'s earliest purpose-built cinemas, seating over 750 seats in the single auditorium. Like many cinemas of the period, it was fitted with an organ. It was seen as a \'scruffy relation\' to the nearby Palladium, and was known as the \'flea pit\'. Sound films began showing in 1929. The neighbouring Brixton Theatre was completely destroyed by bombing in 1940, which allowed the Ritzy to expand into the vacant space. In 1954, it was renovated by noted cinema architect George Coles, who installed CinemaScope: the cinema was renamed "the Pullman" and the organ was removed. It was later renamed "the Classic", before closure in 1
# ...

# %%
print_venue(things_to_do()[0])
# Out:
# Venue_Name: Ritzy Cinema
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Brixton Oval (Coldharbour Ln)', 'London', 'Greater London', 'SW2 1JG', 'United Kingdom']
# Venue_lat: 51.46115325214217
# Venuelng: -0.11501312255859375
# distance: 179
# category: Indie Movies
# #################
# Venue_Name: Electric Brixton
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Town Hall Parade (Brixton Hill)', 'Brixton', 'Greater London', 'SW2 1RJ', 'United Kingdom']
# Venue_lat: 51.4601547818653
# Venuelng: -0.11654054811424354
# distance: 114
# category: Nightclub
# #################
# Venue_Name: David Bowie Mural
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Tunstall Rd', 'Brixton', 'Greater London', 'SW9 8EH', 'United Kingdom']
# Venue_lat: 51.46266393516455
# Venuelng: -0.11540472507476807
# distance: 243
# category: Street Art
# #################
# ...

# %%
def breakfast():
  params = dict(
  client_id='QCLYU41XGKCAAEXJIMGC3QHRK2MQDT3VNRIL4KP4JYOMGRZX',
  client_secret='IKTOYX0OGSQRFQCPTKG4ETTN3PJB1RTRBGDLXLJ1QOI3UVT4',
  v='20210923', #the v parameter is a date in YYYYMMDD format that lets you tell us "I'm prepared for API changes up to this date."
  ll='51.46095,-0.11758', # latitude and longitude
  radius = 500, # area around the place 500 meters
  query='breakfast',
  limit= limit
  )    
  resp = requests.get(url=url, params=params)
  data = json.loads(resp.text)
  return data

# %%
train()
# Out:
# {'meta': {'code': 200, 'requestId': '61998302c40e595bf31d21a7'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad2e539f964a520cee220e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'primary': True,
#          'shortName': 'Train Station'}],
#        'id': '4ad2e539f964a520cee220e3',
#        'location': {'address': 'Atlantic Rd.',
#         'cc': 'GB',
#         'city': 'Brixton',
#         'country': 'United Kingdom',
#         'distance': 259,
#         'formattedAddress': ['Atlantic Rd.',
#          'Brixton',
#          'Greater London',
#          'SW9 8JB',
# ...

# %%
bus_stop()
# Out:
# {'meta': {'code': 200, 'requestId': '619982bf1f367b0c82b197f3'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e493219fa76a07fde7c9a36-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d12b951735',
#          'name': 'Bus Line',
#          'pluralName': 'Bus Lines',
#          'primary': True,
#          'shortName': 'Bus'}],
#        'id': '4e493219fa76a07fde7c9a36',
#        'location': {'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 156,
#         'formattedAddress': ['London', 'Greater London', 'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4599527018742,
# ...

# %%
print(breakfast())
# Out:
# {'meta': {'code': 200, 'requestId': '61954e9535a72e4f44538857'}, 'response': {'suggestedFilters': {'header': 'Tap to show:', 'filters': [{'name': 'Open now', 'key': 'openNow'}]}, 'headerLocation': 'Ferndale', 'headerFullLocation': 'Ferndale, London', 'headerLocationGranularity': 'neighborhood', 'query': 'breakfast', 'totalResults': 21, 'suggestedBounds': {'ne': {'lat': 51.4654500045, 'lng': -0.11037091924572001}, 'sw': {'lat': 51.456449995499995, 'lng': -0.12478908075428}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b767fa6f964a520324f2ee3', 'name': 'San Marino', 'location': {'address': '413 Brixton Rd', 'crossStreet': 'Brixton Station Rd', 'lat': 51.463556392972265, 'lng': -0.11457449633162292, 'labeledLatLngs': [{'label': 'display', 'lat': 51.463556392972265, 'lng': -0.11457449633162292}], 'distance':
# ...

# %%
print_venue(breakfast())
# Out:
# Venue_Name: San Marino
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['413 Brixton Rd (Brixton Station Rd)', 'Brixton', 'Greater London', 'SW9 7DG', 'United Kingdom']
# Venue_lat: 51.463556392972265
# Venuelng: -0.11457449633162292
# distance: 357
# category: Breakfast
# #################
# Venue_Name: Federation Coffee
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Unit 77-78, Brixton Village, Coldharbour Ln. (Atlantic Rd.)', 'Brixton', 'Greater London', 'SW9 8PS', 'United Kingdom']
# Venue_lat: 51.46241288833468
# Venuelng: -0.1117200585980071
# distance: 437
# category: Coffee Shop
# #################
# Venue_Name: Pret A Manger
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['417 Brixton Road', 'Brixton', 'Greater London', 'SW9 8HE', 'United Kingdom']
# Venue_lat: 51.4630530959274
# Venuelng: -0.1145677171792947
# distance: 313
# category: Sandwiches
# ...

# %%
print_venue(breakfast())
print("************************things_to_do*****************************")
print_venue(things_to_do()[0])
print("***********************lunch******************************")
print_venue(lunch())
print("***********************dinner******************************")
print_venue(dinner())
print("***********************nightlife******************************")
print_venue(nightlife())
print("***********************coffee******************************")
print_venue(coffee())
print("***********************train******************************")
print_data_transportation(train())
# Out:
# Venue_Name: San Marino
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['413 Brixton Rd (Brixton Station Rd)', 'Brixton', 'Greater London', 'SW9 7DG', 'United Kingdom']
# Venue_lat: 51.463556392972265
# Venuelng: -0.11457449633162292
# distance: 357
# category: Breakfast
# #################
# Venue_Name: Federation Coffee
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Unit 77-78, Brixton Village, Coldharbour Ln. (Atlantic Rd.)', 'Brixton', 'Greater London', 'SW9 8PS', 'United Kingdom']
# Venue_lat: 51.46241288833468
# Venuelng: -0.1117200585980071
# distance: 437
# category: Coffee Shop
# #################
# Venue_Name: Pret A Manger
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['417 Brixton Road', 'Brixton', 'Greater London', 'SW9 8HE', 'United Kingdom']
# Venue_lat: 51.4630530959274
# Venuelng: -0.1145677171792947
# distance: 313
# category: Sandwiches
# ...

# %%
print_venue(breakfast())
print("************************things_to_do*****************************")
print_venue(things_to_do()[0])
print("***********************lunch******************************")
print_venue(lunch())
print("***********************dinner******************************")
print_venue(dinner())
print("***********************nightlife******************************")
print_venue(nightlife())
print("***********************coffee******************************")
print_venue(coffee())
print("***********************train******************************")
print_data_transportation(train())
# Out:
# Venue_Name: San Marino
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['413 Brixton Rd (Brixton Station Rd)', 'Brixton', 'Greater London', 'SW9 7DG', 'United Kingdom']
# Venue_lat: 51.463556392972265
# Venuelng: -0.11457449633162292
# distance: 357
# category: Breakfast
# #################
# Venue_Name: Federation Coffee
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['Unit 77-78, Brixton Village, Coldharbour Ln. (Atlantic Rd.)', 'Brixton', 'Greater London', 'SW9 8PS', 'United Kingdom']
# Venue_lat: 51.46241288833468
# Venuelng: -0.1117200585980071
# distance: 437
# category: Coffee Shop
# #################
# Venue_Name: Parissi
# Venue_type: Recommended Places
# Venue_Summary: This spot is popular
# Venue_Location: ['76 Atlantic Rd', 'London', 'Greater London', 'United Kingdom']
# Venue_lat: 51.46086484927744
# Venuelng: -0.11107165015813722
# distance: 451
# category: Coffee Shop
# ...

# %%
import sqlite3 as db
# connect to the Airbnb database 
connect = db.connect("/content/drive/MyDrive/Airbnb datasets/Airbnb (1).db")
# Convert DB tabel into dataframe 
listing = pd.read_sql_query("SELECT * FROM listing ", connect)
#crime_data = pd.read_sql_query("SELECT * FROM crime_per_month ", connect)

# %%
# *  # * # MAPBOX  # *  # * #
mapbox_access_token = 'pk.eyJ1IjoiZGluYWtzIiwiYSI6ImNrdjE1ZHFiZzNleGUybnF2enRtNWJneGEifQ.0ko9n8GWZAyu5hVPzcvKJQ'

# %%
import pandas as pd
import numpy as np
import dash                     
from dash import dash_table
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objs as go
import dash_daq as daq


df = pd.read_csv("/content/drive/MyDrive/MSc project/datasets/listing_with_crimeCategories1.csv")
df["bedrooms"] = df["bedrooms"].fillna(0.0).astype(int)
df["price"] = [float(str(i).replace(",", "")) for i in df["price"]]
app = JupyterDash(__name__)

app.layout = html.Div([
    html.Div([
        html.Div([
            # neighbourhood Dropdown menue
            dcc.Dropdown(id='Dropdown1', clearable=False,
                    options=[{'label':str(b),'value':b} for b in sorted(df.neighbourhood_cleansed.unique())],
                    value = "neighbourhood",
                    placeholder="Neighbourhood",
                    multi=True
                    ),
                  ],
        ),
        html.Div([ 
             dcc.Dropdown(id='Dropdown2', clearable=False,
                    options=[{'label':str(b),'value':b} for b in sorted(df.property_type.unique())],
                    value = "property_type", 
                    #value=[b for b in sorted(str(df.host_is_superhost.unique()))]
                    placeholder="Property type",  
                     multi=True
                    ),

            dcc.Dropdown(id='Dropdown3',
                    options=[{'label':str(b),'value':b} for b in sorted(df.bedrooms.unique())],
                    value= "bedrooms", 
                    placeholder="Number of Bedroom",  
                    multi=True,
                    
            ),
                  

            daq.NumericInput(
                  label='Minimum price',
                  id='Minimum_price',
                      min=0,
                      max=10000,
                      value=0, 
                      size=120
                  
              ),
              daq.NumericInput(
                  label='Maximum price',
                  id='Maximum_price',
                    min=0,
                    max=10000,
                    value=0, 
                    size=120
              ),
    
        ],
        ),
 # Map-legend
            html.Ul([
                html.Li("Low crime rate", className='circle', style={'background': '#00FF00','color':'black',
                    'list-style':'none','text-indent': '17px'}),
                html.Li("Middel crime rate", className='circle', style={'background': '#FFFF00','color':'black',
                    'list-style':'none','text-indent': '17px','white-space':'nowrap'}),
                html.Li("High crime rate", className='circle', style={'background': '#FF0000','color':'black',
                    'list-style':'none','text-indent': '17px'})
            ], style={'border-bottom': 'solid 3px', 'border-color':'#00FC87','padding-top': '6px'}
            ),
        # Map
        html.Div([
            dcc.Graph(id='map', config={'displayModeBar': True, 'scrollZoom': True},
                style={'background':'#00FC87','padding-left':'2px',
                       'height':'100vh'}
            )
        ], 
        ),
        
      

    ],
    ),

], 
)


@app.callback(Output('map', 'figure'),
              [Input('Dropdown1', 'value'), 
               Input("Dropdown2", "value"), 
               Input("Dropdown3", "value"), 
               Input("Minimum_price", "value"),
               Input("Maximum_price", "value"), 
              ])
def update_figure(Dropdown1, Dropdown2, Dropdown3, Minimum_price, Maximum_price):
    df_sub = df[(df['neighbourhood_cleansed'].isin(Dropdown1)) & 
                (df["property_type"].isin(Dropdown2)) &
                (df["bedrooms"].isin(Dropdown3)) &
                (df["price"].isin(range(Minimum_price, Maximum_price)))  ] 
  
    # Create figure
    locations=[go.Scattermapbox(
                     lon = df_sub['longitude'],
                     lat = df_sub['latitude'],
                     mode='markers',
                     marker={'color' : df_sub["color"], 'size': 10 },
                     unselected={'marker' : {'opacity':1}},
                     selected={'marker' : {'opacity':0.5, 'size':10}},
                     hoverinfo='text',
                     hovertext=df_sub['name'],
                     customdata=df_sub['picture_url']
     )] 
  
    # Return London map 
    return {
        'data': locations,
        'layout': go.Layout(
            uirevision= 'foo', #preserves state of figure/map after callback activated
            clickmode= 'event+select',
            hovermode='closest',
            hoverdistance=2,
            title=dict(text="Where do you want to stay in London?",font=dict(size=30, color='green')),            
            
            mapbox=dict(
                accesstoken='pk.eyJ1IjoiZGluYWtzIiwiYSI6ImNrdjE1ZHFiZzNleGUybnF2enRtNWJneGEifQ.0ko9n8GWZAyu5hVPzcvKJQ',
                bearing=25,
                center=dict(
                    # London lat and long
                    lat= 51.509865,
                    lon=-0.118092
                ),
                pitch=40,
                zoom=8
            ),
        )
    }

if __name__ == '__main__':
  app.run_server(port=8052)
# Out:
# Dash app running on:

# %%
import sqlite3 as sql
from sqlalchemy import create_engine
airbnb_connection = create_engine("sqlite:////content/drive/MyDrive/MSc project/datasets/Airbnb.db")

# %%
print("Connected to SQLite")
sql_delete_query = """DELETE from listing where id_test IS NULL OR id_test  = ''"""
airbnb_connection.execute(sql_delete_query)
print("Record deleted successfully ")
# Out:
# Connected to SQLite
# Record deleted successfully

# %%
import pandas as pd
listing = pd.read_sql_query("SELECT * from listing", airbnb_connection)

# %%
len(listing)
# Out:
# 50765
